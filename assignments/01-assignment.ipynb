# %% [markdown]
# # Assignment 01: Understanding AI Fundamentals
#
# DATASCI 101: Introduction to AI Applications
#
# Emory University
#
# ## Instructions
#
# This assignment covers material from **Lectures 01-03**: Introduction to
# AI, History of AI, and Dataset Design.
#
# **Guidelines:**
#
# - You are **encouraged** to use ChatGPT, Claude, Gemini, or other LLMs
#   to help you explore these questions
#
# - However, you must **write your answers in your own words** and
#   demonstrate genuine understanding
#
# - Please **disclose which AI tool you used** (if any)
#
# - Your answers should be thoughtful and show critical thinking, not just
#   copy-pasted LLM outputs
#
# - **Please include screenshots** of your interactions with AI tools
#
# - However, **reflection questions must be written in text**, not just
#   screenshots
#
# - ## Submit this assignment as a **PDF** (preferred) or Word document via Canvas
#
# ### Question 1: AI Definition Challenge
#
# Ask ChatGPT or another LLM to explain what “artificial intelligence”
# means in **three different ways**:
#
# 1.  As if explaining to a 10-year-old child
# 2.  As a technical definition for computer science students
# 3.  As a philosopher might define it
#
# Then **compare** these three explanations. What key elements appear in
# all three? What’s different?
#
# ------------------------------------------------------------------------
#
# *Your answer:*
#
#
#
#
#
#
#
# ------------------------------------------------------------------------
#
# ### Question 2: Hallucination Hunt
#
# Ask ChatGPT or another LLM: *“Who won the Nobel Prize in Literature in
# 2030?”*
#
# Observe how it responds. Does it:
#
# - Admit it doesn’t know?
# - Make something up (hallucinate)?
# - Correctly identify this as a future date?
#
# Try **3 different prompts** that might cause the AI to hallucinate
# (e.g., asking about obscure historical events, fictional details, or
# very specific claims). Document what happens.
#
# ------------------------------------------------------------------------
#
# *Your answer:*
#
#
#
#
#
#
#
# ------------------------------------------------------------------------
#
# ### Question 3: ELIZA Experiment
#
# Visit the ELIZA chatbot (one of the first AI systems from 1966):
# <https://anthay.github.io/eliza.html>
#
# Have a conversation with ELIZA for at least 5 exchanges. Then have a
# similar conversation with ChatGPT.
#
# **Compare:**
#
# 1.  How does ELIZA work? (pattern matching, no real understanding)
# 2.  How does ChatGPT seem different?
# 3.  What can ChatGPT do that ELIZA cannot?
# 4.  Is there anything ELIZA does that still feels “clever” despite being
#     so simple?
#
# ------------------------------------------------------------------------
#
# *Your answer:*
#
#
#
#
#
#
#
# ------------------------------------------------------------------------
#
# ### Question 4: Transformer Explainer Activity
#
# Visit Georgia Tech’s **Transformer Explainer**:
# <https://poloclub.github.io/transformer-explainer/>
#
# Experiment with the tool and answer:
#
# 1.  Type a sentence and observe the **attention patterns**. Which words
#     attend strongly to each other? Take a screenshot if possible.
#
# 2.  Try changing the **temperature** setting. What differences do you
#     notice between low temperature (0.2) and high temperature (1.0)?
#
# 3.  In your own words, explain what “self-attention” does. Use an
#     analogy if helpful.
#
# ------------------------------------------------------------------------
#
# *Your answer:*
#
#
#
#
#
#
#
# ------------------------------------------------------------------------
#
# ### Question 5: Garbage In, Garbage Out Demonstration
#
# Try to “confuse” an LLM with deliberately misleading information:
#
# 1.  Tell it something false and see if it corrects you or goes along
#     with it (e.g., “Since the Eiffel Tower is in London…”)
#
# 2.  Ask it to do a task with contradictory instructions
#
# 3.  Provide it with a biased prompt and see if the response reflects
#     that bias
#
# Document what happens in each case. How does this illustrate the
# “garbage in, garbage out” principle?
#
# ------------------------------------------------------------------------
#
# *Your answer:*
#
#
#
#
#
#
#
# ------------------------------------------------------------------------
#
# ### Bonus Question: Your AI Use Policy
#
# Based on everything you’ve learned in Lectures 01-03, write a **personal
# AI use policy** for yourself.
#
# Address:
#
# 1.  **When will you use AI tools?** (What tasks are they good for?)
# 2.  **When will you NOT use AI tools?** (What are the risks?)
# 3.  **How will you verify AI outputs?** (Given what you know about
#     hallucinations and bias)
# 4.  **What ethical considerations will guide your use?**
#
# This should reflect genuine thought about responsible AI use, not just
# generic statements.
#
# ------------------------------------------------------------------------
#
# *Your answer:*
